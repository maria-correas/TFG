# %% [markdown]
# # Análisis del conjunto de datos Agencia para el Empleo. Perfiles de personas inscritas

# %% [markdown]
# ### Carga de módulos

# %%
# Librería para el manejo de dataframes
import pandas as pd

#Librería para visualización de datos
import plotly.express as px

# %% [markdown]
# ### Lectura del dataset

# %%
df_original = pd.read_csv('agencia_empleo_inscritos_2021.csv', sep = ';')

# %%
df = df_original.copy()

# %% [markdown]
# Muestra del conjunto de datos

# %%
print(df.shape)
df.head()
# Out:
# (16189, 11)
#   Fecha de Inscripción  Género            Distrito      Tramos de Edad  \
# 0               ene-21   Mujer  Puente De Vallecas  Entre 46 y 55 años
# 1               ene-21   Mujer       Ciudad Lineal  Entre 26 y 35 años
# 2               ene-21  Hombre              Centro  Entre 46 y 55 años
# 3               ene-21   Mujer              Latina  Entre 36 y 45 años
# 4               ene-21  Hombre  Puente De Vallecas  Entre 36 y 45 años
#
#        Nacionalidad  Código Objetivo Profesional 1  \
# 0          Española                         9443.0
# 1  Extracomunitaria                         9310.0
# 2          Española                         4424.0
# 3          Española                         3613.0
# 4  Extracomunitaria                         9811.0
#
#                               Objetivo Profesional 1  \
# 0                               Barrenderos y afines
# 1                                Ayudantes de cocina
# 2                                     Teleoperadores
# 3          Asistentes de dirección y administrativos
# 4  Peones del transporte de mercancías y descarga...
#
#    Código Objetivo Profesional 2  \
# 0                         9210.0
# 1                         9210.0
# 2                         4424.0
# 3                         2511.0
# 4                         4411.0
#
#                               Objetivo Profesional 2  \
# 0  Personal de limpieza de oficinas, hoteles y ot...
# 1  Personal de limpieza de oficinas, hoteles y ot...
# 2                                     Teleoperadores
# 3                                           Abogados
# 4                Empleados de información al usuario
#
#    Código Objetivo Profesional 3  \
# 0                         9700.0
# 1                         5710.0
# 2                         5825.0
# 3                         4500.0
# 4                         5120.0
#
#                               Objetivo Profesional 3
# 0            Peones de las industrias manufactureras
# 1  Trabajadores de los cuidados personales a domi...
# 2                                   Guías de turismo
# 3  Empleados administrativos con tareas de atenci...
# 4                              Camareros asalariados

# %% [markdown]
# ### Análisis y limpieza

# %%
#Tamaño del conjunto de datos
print(f' Las dimensiones del conjunto de datos son: {df.shape}')
# Out:
#  Las dimensiones del conjunto de datos son: (16189, 11)

# %%
#Se eliminan valores duplicados
df.drop_duplicates(inplace = True)
print(f' Las dimensiones del conjunto de datos son:{df.shape}')
# Out:
#  Las dimensiones del conjunto de datos son:(15607, 11)

# %%
#Valores nulos totales
df.isnull().sum()
# Out:
# Fecha de Inscripción                0
# Género                              0
# Distrito                            0
# Tramos de Edad                      0
# Nacionalidad                        0
# Código Objetivo Profesional 1     749
# Objetivo Profesional 1            749
# Código Objetivo Profesional 2    3594
# Objetivo Profesional 2           3594
# Código Objetivo Profesional 3    5760
# Objetivo Profesional 3           5760
# dtype: int64

# %%
#Porcentaje de nulos
df.isnull().sum()/len(df)*100
# Out:
# Fecha de Inscripción              0.000000
# Género                            0.000000
# Distrito                          0.000000
# Tramos de Edad                    0.000000
# Nacionalidad                      0.000000
# Código Objetivo Profesional 1     4.799129
# Objetivo Profesional 1            4.799129
# Código Objetivo Profesional 2    23.028128
# Objetivo Profesional 2           23.028128
# Código Objetivo Profesional 3    36.906516
# Objetivo Profesional 3           36.906516
# dtype: float64

# %%
# Columnas del dataframe
df.columns
# Out:
# Index(['Fecha de Inscripción', 'Género', 'Distrito', 'Tramos de Edad',
#        'Nacionalidad', 'Código Objetivo Profesional 1',
#        'Objetivo Profesional 1', 'Código Objetivo Profesional 2',
#        'Objetivo Profesional 2', 'Código Objetivo Profesional 3',
#        'Objetivo Profesional 3'],
#       dtype='object')

# %%
#Se eliminan las variables Código Objetivo Profesional 1 , Código Objetivo Profesional 2, 
#Código Objetivo Profesional 3,'Objetivo Profesional 2','Objetivo Profesional 3'

df = df[['Fecha de Inscripción', 'Género', 'Distrito', 'Tramos de Edad',
       'Nacionalidad',
       'Objetivo Profesional 1']]

# %%
#Se eliminan las variables con 'Género', 'Distrito', 'Tramos de Edad','Nacionalidad' 'Objetivo Profesional 1' nulos 
df = df.dropna(subset=['Género', 'Distrito', 'Tramos de Edad','Nacionalidad', 'Objetivo Profesional 1'])

# %%
#Valores nulos totales 2
df.isnull().sum()
# Out:
# Fecha de Inscripción      0
# Género                    0
# Distrito                  0
# Tramos de Edad            0
# Nacionalidad              0
# Objetivo Profesional 1    0
# dtype: int64

# %%
#Se analiza la variable tramos de edad
#Distribución de registros por tramo de edad
df.value_counts('Tramos de Edad')
# Out:
# Tramos de Edad
# Entre 46 y 55 años    3024
# Entre 26 y 35 años    3021
# Entre 36 y 45 años    2978
# Menor de 25 años      2251
# Entre 56 y 65 años    1231
#                       ...
# 1954                     2
# 2005                     1
# 1953                     1
# 1950                     1
# 1947                     1
# Length: 61, dtype: int64

# %%
df['Tramos de Edad'].unique()
# Out:
# array(['Entre 46 y 55 años', 'Entre 26 y 35 años', 'Entre 36 y 45 años',
#        'Entre 56 y 65 años', 'Menor de 25 años', 'Mayor de 65 años',
#        '1979', '1977', '1991', '1999', '1974', '1970', '1994', '1964',
#        '1959', '1986', '1998', '1971', '1996', '1985', '2000', '2001',
#        '1987', '1966', '1997', '1983', '1969', '2003', '1973', '1978',
#        '1995', '1980', '1993', '1982', '1981', '1988', '1975', '1962',
#        '1992', '1990', '1968', '1984', '1989', '1972', '1976', '2002',
#        '1960', '1967', '2004', '1963', '1958', '1961', '1965', '1957',
#        '1956', '1950', '1955', '1953', '1954', '1947', '2005'],
#       dtype=object)

# %%
# Se eliminan tramos de edad que se corresponden con un año y no un rango de edad 
no_validos = ['1979', '1977', '1991', '1999', '1974', '1970', '1994', '1964',
       '1959', '1986', '1998', '1971', '1996', '1985', '2000', '2001',
       '1987', '1966', '1997', '1983', '1969', '2003', '1973', '1978',
       '1995', '1980', '1993', '1982', '1981', '1988', '1975', '1962',
       '1992', '1990', '1968', '1984', '1989', '1972', '1976', '2002',
       '1960', '1967', '2004', '1963', '1958', '1961', '1965', '1957',
       '1956', '1950', '1955', '1953', '1954', '1947', '2005']
df['Tramos de Edad'] = df['Tramos de Edad'].apply(lambda x: False if x in no_validos else x)
df.drop(df[df['Tramos de Edad'] == False].index, inplace = True)

# %%
#Distribución de registros por tramo de edad 2
df.value_counts('Tramos de Edad')
# Out:
# Tramos de Edad
# Entre 46 y 55 años    3024
# Entre 26 y 35 años    3021
# Entre 36 y 45 años    2978
# Menor de 25 años      2251
# Entre 56 y 65 años    1231
# Mayor de 65 años        46
# dtype: int64

# %%
df['Objetivo Profesional 1'].nunique()
# Out:
# 357

# %%
# Se decide reducir en numero de objetivos profesionales 
objetivos_profesionales =['Especialistas en administración de política de empresas','Directores y gerentes de restaurantes','Economistas','Profesionales de la publicidad y la comercialización','Operadores de telemarketing','Vendedores en tiendas y almacenes' ,                            
 'Analistas de gestión y organización', 'Empleados de control de personal y nóminas','Asistentes de dirección y administrativos','Empleados de contabilidad',                    
 'Analistas y diseñadores de software y multimedia no clasificados bajo otros epígrafes', 'Técnicos de ingeniería de las telecomunicaciones', 'Ingenieros técnicos en telecomunicaciones','Técnicos de la Web','Especialistas en bases de datos y en redes informáticas no clasificados bajo otros epígrafes','Programadores informáticos',               
'Guías de turismo','Jefes de sección de tiendas y almacenes','Empleados de agencias de viajes','Directores y gerentes de bares, cafeterías y similares','Ayudantes de cocina','Recepcionistas de hoteles','Preparadores de comidas rápidas',                        
'Especialistas en tratamientos de estética, bienestar y afines','Peluqueros',
'Montadores y ensambladores no clasificados en otros epígrafes','Mantenedores de edificios',                 
'Ingenieros electrónicos', 'Mecánicos y reparadores de equipos eléctricos','Ingenieros técnicos forestales y del medio natural','Técnicos forestales y del medio natural','Otros técnicos de las ciencias físicas, químicas, medioambientales y de las ingenierías',                 
 'Mecánicos y ajustadores de vehículos de motor','Limpiadores de vehículos',   
'Peones agropecuarios',  'Peones ganaderos','Ingenieros técnicos agrícolas','Peones agrícolas en huertas, invernaderos, viveros y jardines', 'Ingenieros agrónomos','Matarifes y trabajadores de las industrias cárnicas',                                      
'Encofradores y operarios de puesta en obra de hormigón',                       
'Coreógrafos y bailarines','Bañistas-socorristas',                                             
'Técnicos superiores en dietética','Técnicos en radioterapia','Técnicos superiores en documentación sanitaria','Dietistas y nutricionistas','Técnicos en imagen para el diagnóstico','Técnicos en laboratorio de diagnóstico clínico','Técnicos en electrónica, especialidad en electromedicina','Auxiliares de enfermería hospitalaria','Técnicos de emergencias sanitarias',                                                                                 
'Técnicos de grabación audiovisual','Diseñadores gráficos y multimedia',                               
'Ingenieros mecánicos','Ajustadores y operadores de máquinas-herramienta','Ensambladores de maquinaria mecánica','Ingenieros técnicos industriales y de producción','Trabajadores de la fabricación de herramientas, mecánico-ajustadores, modelistas, matriceros y afines',                                  
'Técnicos en ciencias físicas y químicas','Operadores en plantas industriales químicas',                         
 'Artistas de artes plásticas y visuales','Ebanistas y trabajadores afines','Trabajadores de procesos de encuadernación', 'Operadores de máquinas de coser y bordar','Artesanos no clasificados bajo otros epígrafes'  ]

# %%
len(objetivos_profesionales)
# Out:
# 66

# %%
# Se eliminan los registros que contienen objetivos profesionales que no se encuentran entre los seleccionados
df['Objetivo Profesional 1'] = df['Objetivo Profesional 1'].apply(lambda x: False if x not in objetivos_profesionales else x)
df.drop(df[df['Objetivo Profesional 1'] == False].index, inplace = True)

# %% [markdown]
# ### Distribución de las variables

# %%
tramos_edad = ['Menor de 25 años', 'Entre 26 y 35 años', 'Entre 36 y 45 años', 'Entre 46 y 55 años', 'Entre 56 y 65 años','Mayor de 65 años']

# %%
#Distribución de los tramos de edad
fig = px.histogram(df, x='Tramos de Edad')
fig.update_xaxes(categoryorder='array', categoryarray= tramos_edad)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="97aa2306-b330-408e-8e27-7c72cc54cb56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97aa2306-b330-408e-8e27-7c72cc54cb56")) {                    Plotly.newPlot(                        "97aa2306-b330-408e-8e27-7c72cc54cb56",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Tramos de Edad=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Entre 26 y 35 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 56 y 65 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 36 y 45 a\u00f1os","Menor de 25 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 26 y 35 a\u00f1os","Menor de 25 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 56 y 65 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 26 y 35 a\u00f1os","Menor de 25 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 36 y 45 a\u00f1os","Menor de 25 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 36 y 45 a\u00f1os","Menor de 25 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 36 y 45 a\u00f1os","Menor de 25 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 46 y 55 a\u00f1os","Menor de 25 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 56 y 65 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 46 y 55 a\u00f1os","Menor de 25 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 36 y 45 a\u00f1os","Menor de 25 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 26 y 35 a\u00f1os","Menor de 25 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 26 y 35 a\u00f1os","Menor de 25 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 26 y 35 a\u00f1os","Menor de 25 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 36 y 45 a\u00f1os","Menor de 25 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 46 y 55 a\u00f1os","Menor de 25 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 26 y 35 a\u00f1os","Menor de 25 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 36 y 45 a\u00f1os","Menor de 25 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 56 y 65 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 46 y 55 a\u00f1os","Menor de 25 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 56 y 65 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 26 y 35 a\u00f1os","Menor de 25 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 36 y 45 a\u00f1os","Menor de 25 a\u00f1os","Entre 46 y 55 a\u00f1os","Menor de 25 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 46 y 55 a\u00f1os","Menor de 25 a\u00f1os","Menor de 25 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 26 y 35 a\u00f1os","Menor de 25 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 26 y 35 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 26 y 35 a\u00f1os","Menor de 25 a\u00f1os","Entre 46 y 55 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre 36 y 45 a\u00f1os","Entre ...

# %%
#Distribución de registros por género 
df.value_counts('Género')
# Out:
# Género
# Mujer     2510
# Hombre    1168
# dtype: int64

# %%
#Distribución del género
fig = px.histogram(df, x='Género')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5a5d6364-f57d-4bfa-bca3-751b5c5870fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a5d6364-f57d-4bfa-bca3-751b5c5870fa")) {                    Plotly.newPlot(                        "5a5d6364-f57d-4bfa-bca3-751b5c5870fa",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"G\u00e9nero=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Mujer","Mujer","Mujer","Hombre","Hombre","Hombre","Mujer","Hombre","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Hombre","Hombre","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Hombre","Mujer","Hombre","Mujer","Hombre","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Hombre","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Hombre","Hombre","Hombre","Mujer","Mujer","Hombre","Mujer","Hombre","Hombre","Mujer","Hombre","Mujer","Mujer","Hombre","Hombre","Mujer","Mujer","Hombre","Mujer","Mujer","Hombre","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Hombre","Hombre","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Hombre","Mujer","Hombre","Hombre","Hombre","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Hombre","Mujer","Hombre","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Hombre","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Hombre","Hombre","Hombre","Mujer","Hombre","Hombre","Hombre","Mujer","Hombre","Hombre","Mujer","Hombre","Hombre","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Hombre","Hombre","Mujer","Hombre","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Hombre","Hombre","Hombre","Mujer","Mujer","Hombre","Hombre","Hombre","Mujer","Hombre","Mujer","Mujer","Hombre","Hombre","Hombre","Hombre","Mujer","Hombre","Mujer","Hombre","Mujer","Hombre","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Hombre","Hombre","Hombre","Hombre","Mujer","Mujer","Mujer","Mujer","Hombre","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Hombre","Hombre","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Hombre","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Hombre","Hombre","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Hombre","Hombre","Hombre","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Hombre","Hombre","Hombre","Hombre","Hombre","Hombre","Mujer","Mujer","Hombre","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Mujer","Hombre","Hombre","Mujer","Mujer","Mujer","Mujer","Hombre","Mujer","Hombre","Mujer","Hombre","Mujer","Mujer","Hombre","Mujer","Mujer","Hombre","Mujer","Mujer","Mujer","Hombre","Mujer","Hombre","Mujer","Hombre","Hombre","Mujer","Mujer","Hombre","Hombre","Muje ...

# %%
#Distribución de registros por nacionalidad
df.value_counts('Nacionalidad')
# Out:
# Nacionalidad
# Española            2646
# Extracomunitaria     883
# Comunitaria          149
# dtype: int64

# %%
#Distribución de la nacionalidad
fig = px.histogram(df, x='Nacionalidad')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4b31c598-bdbf-49cb-a48e-62eb453f89b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b31c598-bdbf-49cb-a48e-62eb453f89b1")) {                    Plotly.newPlot(                        "4b31c598-bdbf-49cb-a48e-62eb453f89b1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Nacionalidad=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Comunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Comunitaria","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Extracomunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Extracomunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Extracomunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Extracomunitaria","Comunitaria","Extracomunitaria","Espa\u00f1ola","Extracomunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Extracomunitaria","Extracomunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Comunitaria","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Extracomunitaria","Extracomunitaria","Extracomunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Extracomunitaria","Extracomunitaria","Extracomunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Comunitaria","Extracomunitaria","Espa\u00f1ola","Espa\u00f1ola","Comunitaria","Espa\u00f1ola","Espa\u00f1ola","Comunitaria","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Espa\u00f1ola","Extracomunitaria","Extracomunitaria","Extracomunitaria","Extracomunit ...

# %%
#Distribución de registros por distrito
df.value_counts('Distrito')
# Out:
# Distrito
# Otro Municipio         525
# Puente De Vallecas     348
# Carabanchel            346
# Latina                 273
# Villaverde             233
# Ciudad Lineal          198
# Usera                  179
# Arganzuela             155
# Centro                 142
# San Blas               141
# Villa De Vallecas      141
# Vicálvaro              139
# Fuencarral-el Pardo    134
# Tetuán                 125
# Hortaleza              116
# Moratalaz               89
# Chamberí                83
# Retiro                  71
# Salamanca               68
# Barajas                 61
# Moncloa-aravaca         57
# Chamartín               54
# dtype: int64

# %%
distritos = ['Ciudad Lineal',
 'Latina',
 'Puente De Vallecas',
 'Arganzuela',
 'Moratalaz',
 'San Blas',
 'Hortaleza',
 'Carabanchel',
 'Retiro',
 'Fuencarral-el Pardo',
 'Usera',
 'Otro Municipio',
 'Vicálvaro',
 'Chamartín',
 'Chamberí',
 'Moncloa-aravaca',
 'Centro',
 'Tetuán',
 'Villaverde',
 'Villa De Vallecas',
 'Salamanca',
 'Barajas']

# %%
#Distribución del distrito
fig = px.histogram(df, x='Distrito')
fig.update_xaxes(categoryorder='array', categoryarray= distritos)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a3265e6f-992e-4836-94a3-f60f4a316275" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3265e6f-992e-4836-94a3-f60f4a316275")) {                    Plotly.newPlot(                        "a3265e6f-992e-4836-94a3-f60f4a316275",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Distrito=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Ciudad Lineal","Latina","Ciudad Lineal","Puente De Vallecas","Arganzuela","Moratalaz","Latina","San Blas","Hortaleza","Puente De Vallecas","Carabanchel","Retiro","Hortaleza","Latina","Puente De Vallecas","Latina","Fuencarral-el Pardo","Usera","Puente De Vallecas","San Blas","Ciudad Lineal","Carabanchel","Otro Municipio","Latina","Retiro","Otro Municipio","Vic\u00e1lvaro","Latina","Latina","Latina","Vic\u00e1lvaro","Puente De Vallecas","Fuencarral-el Pardo","Chamart\u00edn","Otro Municipio","Chamber\u00ed","San Blas","San Blas","Hortaleza","Arganzuela","Moncloa-aravaca","Carabanchel","Fuencarral-el Pardo","Moncloa-aravaca","Carabanchel","Otro Municipio","Ciudad Lineal","Ciudad Lineal","Carabanchel","Centro","Puente De Vallecas","Ciudad Lineal","Tetu\u00e1n","Arganzuela","Carabanchel","Moncloa-aravaca","Otro Municipio","Hortaleza","Moratalaz","Carabanchel","Villaverde","Villaverde","Vic\u00e1lvaro","Otro Municipio","Villa De Vallecas","Otro Municipio","Otro Municipio","Chamart\u00edn","Carabanchel","Puente De Vallecas","Puente De Vallecas","Usera","Carabanchel","Hortaleza","Villaverde","Tetu\u00e1n","Carabanchel","Usera","Retiro","Carabanchel","Carabanchel","Puente De Vallecas","Vic\u00e1lvaro","Latina","Hortaleza","Latina","Carabanchel","Otro Municipio","Ciudad Lineal","Carabanchel","Vic\u00e1lvaro","San Blas","Usera","Carabanchel","Tetu\u00e1n","Latina","Vic\u00e1lvaro","Vic\u00e1lvaro","Vic\u00e1lvaro","Puente De Vallecas","Carabanchel","Ciudad Lineal","Vic\u00e1lvaro","Ciudad Lineal","Otro Municipio","Centro","Puente De Vallecas","Puente De Vallecas","Chamber\u00ed","Latina","Puente De Vallecas","Hortaleza","Salamanca","Villaverde","Usera","Barajas","Chamart\u00edn","Ciudad Lineal","San Blas","Vic\u00e1lvaro","Latina","Arganzuela","Moncloa-aravaca","Centro","Moratalaz","Latina","Chamber\u00ed","Puente De Vallecas","Ciudad Lineal","Retiro","Puente De Vallecas","Barajas","San Blas","Retiro","San Blas","Moncloa-aravaca","Moncloa-aravaca","Latina","Arganzuela","Usera","Puente De Vallecas","San Blas","Ciudad Lineal","San Blas","Tetu\u00e1n","Arganzuela","Carabanchel","Retiro","Carabanchel","Centro","Puente De Vallecas","Otro Municipio","Arganzuela","Puente De Vallecas","Latina","San Blas","Otro Municipio","Hortaleza","Ciudad Lineal","Otro Municipio","Puente De Vallecas","Usera","San Blas","Usera","Moratalaz","Carabanchel","Usera","Latina","Otro Municipio","Fuencarral-el Pardo","Villaverde","Salamanca","Villaverde","Latina","Otro Municipio","Puente De Vallecas","Chamber\u00ed","Otro Municipio","San Blas","Otro Municipio","Tetu\u00e1n","Otro Municipio","Tetu\u00e1n","Hortaleza","Carabanchel","Carabanchel","Carabanchel","Moratalaz","Latina","Tetu\u00e1n","Moratalaz","Fuencarral-el Pardo","Salamanca","Tetu\u00e1n","Vic\u00e1lvaro","Latina","Otro Municipio","Moratalaz","Otro Municipio","Puente De Vallecas","Chamber\u00ed","Arganzuela","Otro Municipio","Retiro","Hortaleza","Ciudad Lineal","Latina","Usera","Centro","Latina","Villaverde","Arganzuela","Centro","Ciudad Lineal","Centro","Vic\u00e1lvaro","Carabanchel","Puente De Vallecas","Centro","Arganzuela","Villaverde","Hortaleza","San Blas","San Blas","Latina","Villaverde","Ciudad Lineal","Tetu\u00e1n","Fuencarral- ...

# %%
#Distribución de registros por fecha de inscripción
df.value_counts('Fecha de Inscripción')
# Out:
# Fecha de Inscripción
# feb-21    532
# abr-21    509
# may-21    480
# mar-21    447
# jun-21    383
# sep-21    378
# oct-21    301
# jul-21    225
# ene-21    222
# ago-21    201
# dtype: int64

# %%
fechas = ['ene-21',
 'feb-21',
 'mar-21',
 'abr-21',
 'may-21',
 'jun-21',
 'jul-21',
 'ago-21',
 'sep-21',
 'oct-21']

# %%
#Distribución de los tramos de edad
fig = px.histogram(df, x='Fecha de Inscripción')
fig.update_xaxes(categoryorder='array', categoryarray= fechas)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="040e8fbe-fbb0-4d3e-9345-6b44bc27adfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("040e8fbe-fbb0-4d3e-9345-6b44bc27adfb")) {                    Plotly.newPlot(                        "040e8fbe-fbb0-4d3e-9345-6b44bc27adfb",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Fecha de Inscripci\u00f3n=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","feb-21","feb-21","ene-21","feb-21","ene-21","feb-21","feb-21","feb-21","feb-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","feb-21","feb-21","feb-21","feb-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","ene-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","feb-21","f ...

# %% [markdown]
# ### Conjunto de datos final

# %%
#Tamaño del conjunto de datos
print(f' Las dimensiones del conjunto de datos tras el análisis son: {df.shape}')
# Out:
#  Las dimensiones del conjunto de datos tras el análisis son: (3678, 6)

# %%
df.head()
# Out:
#   Fecha de Inscripción  Género            Distrito      Tramos de Edad  \
# 1               ene-21   Mujer       Ciudad Lineal  Entre 26 y 35 años
# 3               ene-21   Mujer              Latina  Entre 36 y 45 años
# 5               ene-21   Mujer       Ciudad Lineal  Entre 36 y 45 años
# 6               ene-21  Hombre  Puente De Vallecas  Entre 26 y 35 años
# 7               ene-21  Hombre          Arganzuela  Entre 36 y 45 años
#
#        Nacionalidad                     Objetivo Profesional 1
# 1  Extracomunitaria                        Ayudantes de cocina
# 3          Española  Asistentes de dirección y administrativos
# 5          Española                        Ayudantes de cocina
# 6          Española                 Programadores informáticos
# 7          Española  Asistentes de dirección y administrativos

# %%
#Se almacena el dataframe en un csv
df.to_csv('agencia_empleo_procesados.csv')
